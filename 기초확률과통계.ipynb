# %%
print("김소현")
print("22")
# Out:
# 김소현
# 22

# %%
a=[2, 3, 4, 5, 6 ]
rev_a=[]
for i in range(len(a)):
  rev_a.append(a.pop())
print("a=", [2,3,4,5,6])
print("rev_a=", rev_a)
# Out:
# a= [2, 3, 4, 5, 6]
# rev_a= [6, 5, 4, 3, 2]
